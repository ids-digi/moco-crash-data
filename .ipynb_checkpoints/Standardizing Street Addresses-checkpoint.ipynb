# %% [markdown]
# # Standardizing street addresses
# This script will normalize the addresses in the MoCo car crash data as much as possible and make it easier to identify common intersections.
# MAKE SURE TO RUN `CAR CRASH DATA CLEANING` FIRST

# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)

# %% [markdown]
# I'll start by cleaning one of the spreadsheets, the 2022 data, for speed purposes before applying the cleaning functions to the master spreadsheet.

# %%
df = pd.read_csv('source-data/moco-crash-2022.csv', 
                 usecols=['Collision Date','Roadway Id','Intersecting Road'],
                 dtype={'Roadway Id': 'string'},
                 parse_dates=['Collision Date']
                )
df
# Out:
#      Collision Date           Roadway Id      Intersecting Road
# 0        2022-01-07                 I69N            STATE RD 37
# 1        2022-01-08                SR46W              DEER PARK
# 2        2022-01-17             W REEVES                    NaN
# 3        2022-01-04                THIRD            S HAWTHORNE
# 4        2022-01-01          S HENDERSON             E HILLSIDE
# ...             ...                  ...                    ...
# 2245     2022-09-17    W COUNTRY CLUB DR    S OLD STATE ROAD 37
# 2246     2022-09-15            E 10TH ST              E 10TH ST
# 2247     2022-08-20    S COLLEGE MALL RD  E BUICK CADILLAC BLVD
# 2248     2022-06-09          S OLD SR 37              MORMAN RD
# 2249     2022-08-31  S OLD STATE ROAD 37            S ROGERS ST
#
# [2250 rows x 3 columns]

# %%
# replace NA values with empty strings to make cleaning easier
df['Roadway Id'] = df['Roadway Id'].fillna('')
df['Intersecting Road'] = df['Intersecting Road'].fillna('')

# %%
def replace_str(df, str1, str2):
    return df.replace(to_replace=str1, value=str2, regex=True)

# %%
# identify strings to manually replace 
strs_to_replace = [
    ['BLOOMINGTON IN',''],
    ['BLOOMINGTON, IN',''],
    ['S\. ', 'S '],
    ['N\. ', 'N '],
    ['W\. ', 'W '],
    ['E\.','E'],
    ['SOUTH ', 'S '],
    ['NORTH ', 'N '],
    ['WEST ', 'W '],
    ['EAST ', 'E '],
    [' AVE\.', 'AVE'],
    ['AVENUE', 'AVE'],
    ['STREET','ST'],
    ['ST\.','ST'],
    ['PIKE', 'PK'],
    ['ROAD','RD'],
    ['STATE RD','ST RD'],
    ['SR4','SR 4'],
    ['THIRD', '3RD'],
    [' 47401',''],
    ['SR ','ST RD '],
    ['46W', '46 W'],
    ['45W', '45 W'],
    ['STATE 46','ST RD 46'],
    ['S\.R\.','ST RD'],
    ['I 69','I-69'],
    ['I69','I-69'],
    ['INTERSTATE 69','I-69'],
    ['I-69 SOUTH','I-69 S'],
    ['SBOUND','S'],
    ['S BOUND','S'],
    ['S I-69','I-69 S'],
    ['I-69N','I-69 N'],
    ['JORDAN AVE','EAGLESON AVE'],
    ['JORDAN','EAGLESON AVE'],
    ['DRIVE','DR'],
    ['LANE','LN'],
    ['IN-45','ST RD 45'],
    ['W ST RD 45/46 BYPASS','W ST RD 45/46'],
    ['WMAIN','W MAIN'],
    ['ROGERS RD','ROGERS ST'],
    ['BLK ',''],
    ['N JORDAN','N EAGLESON AVE'],
    ['S JORDAN','S EAGLESON AVE'],
    ['E3RD','E 3RD'],
    ['W3RD','W 3RD'],
    ['BLOCK ',''],
    ['STRE','ST'],
    ['E E','E '],
    ['3RD AVE','3RD ST'],
    ['PARKING LOT',''],
    ['ST ST','ST'],
    ['2ND AVE','2ND ST'],
    ['W2ND','W 2ND'],
    ['E2ND','E 2ND'],
    ['E10TH','E 10TH'],
    ['45-46','45/46'],
    ['SR37','ST RD 37'],
    ['SR37S','S ST RD 37'],
    ['OLD SR37','ST RD 37'],
    ['SR37N','N ST RD 37'],
    ['OLD ST RD','ST RD'],
    ['37 BUSINESS','37'],
    ['37 HWY','37'],
    ['HWY 37','ST RD 37'],
    ['OLDSR37','ST RD 37'],
    ['OLD 37','ST RD 37'],
    ['ST RD 37S','S ST RD 37'],
    ['ST RD 37N','N ST RD 37'],
    ['37 RD','37'],
    ['ST RD 37 S','S ST RD 37'],
    ['ST RD 37 N','N ST RD 37'],
    ['OLST RD 37','ST RD 37'],
    ['BUSINESS 37','ST RD 37'],
    ['US37','ST RD 37'],
    ['ST RD 37 S HWY','S ST RD 37'],
    ['ST RD 37 N RD','N ST RD 37'],
    
]

# %%
clean_df = df

for string in strs_to_replace:
    clean_df = replace_str(clean_df,string[0],string[1])

# %%
# extract the `101` from `101 E 2ND ST` and create a new column
def address_num(road):
    address_num_exists = False
    if road:
        # get the first word of the road name
        first_word = road.split(" ")[0]
        # get the length of the road name. if there's only one number, we don't want to identify that as an address num.
        road_len = len(road.split(" "))
        if road_len > 1:
            # if the first word is all numerals, the address num exists
            address_num_exists = bool(re.search("^\d+$",first_word))
    # if it exists, return the address num. if not, return an empty string.
    return first_word if address_num_exists else ''

# %%
# All entries like `101 E 2ND ST` should be `E 2ND ST`
def extract_address_num(road):
    address_num_exists = False
    if road:
        first_word = road.split(" ")[0]
        road_len = len(road.split(" "))
        if road_len > 1:
            address_num_exists = bool(re.search("^\d+$",first_word))
    #         if the address num exists, remove it from the original address. else, return original address.
    return " ".join(road.split(" ")[1:]) if address_num_exists else road

# %%
# All entries like `S 17TH` should be `S 17TH ST`
def number_streets(road):
    if road:
        if bool(re.search('[\d]{1,2}(TH|ST|ND|RD)$',road.strip())):
            road = road.strip() + " ST"
#         if bool(re.search('^[\d]{1,2}(TH|ST|ND|RD)$',road)):
#             road = 
    return road.strip()

# %%
number_streets('E 3RD ')
# Out:
# 'E 3RD ST'

# %%
# remove info after semicolons or colons
def colons(road):
    if road:
        road = road.split(";")[0]
        road = road.split(":")[0]
    return road

# %%
clean_df['Address Number'] = clean_df['Roadway Id'].apply(address_num)
clean_df['Roadway Id'] = clean_df['Roadway Id'].apply(extract_address_num)
clean_df['Roadway Id'] = clean_df['Roadway Id'].apply(colons)

# %%
clean_df
# Out:
#      Collision Date         Roadway Id      Intersecting Road Address Number
# 0        2022-01-07             I-69 N               ST RD 37
# 1        2022-01-08         ST RD 46 W              DEER PARK
# 2        2022-01-17           W REEVES
# 3        2022-01-04                3RD            S HAWTHORNE
# 4        2022-01-01        S HENDERSON             E HILLSIDE
# ...             ...                ...                    ...            ...
# 2245     2022-09-17  W COUNTRY CLUB DR             S ST RD 37
# 2246     2022-09-15          E 10TH ST              E 10TH ST
# 2247     2022-08-20  S COLLEGE MALL RD  E BUICK CADILLAC BLVD
# 2248     2022-06-09         S ST RD 37              MORMAN RD
# 2249     2022-08-31         S ST RD 37            S ROGERS ST
#
# [2250 rows x 4 columns]

# %%
clean_df.sort_values('Roadway Id')['Roadway Id'].unique()
# Out:
# array(['', '10TH', '10TH ST', '1110', '17TH', '17TH ST', '1ST',
#        "3200' S OF SMITHVILLE RD", '3RD', '3RD ST', '45', '45/46 BYPASS',
#        '46', '69', '7TH', '7TH ST', 'ACCESS DR TO HILLTOP GARDENS',
#        'ALEXANDER DR', 'ALLEN ST', 'ATWATER AVE', 'BAYLES',
#        'BEECHWOOD DR', 'BLK. S.OLIVE ST', 'BLOOMFIELD RD', 'CATHERINE ST',
#        'CENTENNIAL DR', 'CHEEKWOOD LN', 'CHURCH LN',
#        'CLEAR CREEK TRAILHEAD NORTH', 'COLLEGE MALL RD', 'CONNAUGHT',
#        'COUNTRY CLUB', 'CURRY PK', 'DANIELS WAY', 'DISCOVERY PARKWAY',
#        'DISCOVERY PKWY', 'DITTEMORE RD', 'DORCHESTER DR', 'E 10TH ST',
#        'E 11TH ST', 'E 12TH ST', 'E 13TH ST', 'E 14TH ST', 'E 15TH ST',
#        'E 16TH ST', 'E 17TH', 'E 17TH ST', 'E 19TH ST', 'E 1ST',
#        'E 2ND ST', 'E 3RD', 'E 3RD ST', 'E 4TH ST', 'E 6TH ST',
#        'E 7TH ST', 'E 8TH ST', 'E 9TH ST', 'E ALLEN ST', 'E ATWATER',
#        'E ATWATER AVE', 'E AUTO MALL RD', 'E BETHEL LN',
#        'E BILL MALLORY BLVD', 'E BUICK CADILLAC BLVD', 'E BURKS DR',
#        'E COTTAGE GROVE AVE', 'E COVENANTER DR', 'E CREEKS EDGE DR',
#        'E DANIEL ST', 'E DAVID DR', 'E DEPOT RD', 'E DILLMAN RD',
#        'E DISCOVERTY PRKWY', 'E DISCOVERY PARKWAY', 'E DISCOVERY PKWY',
#        'E DODDS ST', 'E GARDEN PATH', 'E GLENDORA DR', 'E GOODNIGHT WAY',
#        'E GRIMES LN', 'E HEATHER DR', 'E HILLSIDE DR', 'E HOLLAND DR',
#        'E HUNTER AVE', 'E JOHN HINKLE', 'E JOHN HINKLE PL', 'E JONES AVE',
#        'E KIRKWOOD AVE', 'E LAMPKINS RIDGE RD', 'E LAW LN',
#        'E LINGELBACH LN', 'E LONGVIEW AVE', 'E LORELEI WAY',
#        'E MAIN FORREST RD', 'E MAIN ST', 'E MATLOCK RD', 'E MATTLOCK RD',
#        'E MILLER DR', 'E MOFFETT LN', 'E MONROE DAM RD', 'E MOORES PK',
#        'E N DR', 'E PARK LN', 'E PETE LLIS DR', 'E POINTE RD',
#        'E RAYLETOWN RD', 'E RHORER', 'E RHORER RD', 'E ROBINSON RD',
#        'E ROGERS', 'E ROGERS ST', 'E SAMPLE RD', 'E SARATOGA DR',
#        'E SCHACHT RD', 'E SMITH AVE', 'E SMITHVILLE RD', 'E SOUTHERN DR',
#        'E ST RD 45', 'E ST RD 45/46', 'E ST RD 45/46 BYPASS',
#        'E ST RD 46', 'E STIPP RD', 'E STRATUM WAY', 'E TEMPERANCE ST',
#        'E THORNTON DR', 'E UNIVERSITY RD', 'E UNIVERSITY ST',
#        'E VARSITY LN', 'E WINSLOW RD', 'E WINSLOW RD ', 'E WYLIE FARM RD',
#        'E WYLIE ST', 'EAGLESON AVE', 'EARL YOUNG RD', 'EDGEWOOD DR',
#        'FAIRFAX RD', 'FLEENER AVE', 'FOREST RD', 'GATES DR', 'GIFFORD',
#        'GILMORE', 'GUTHRIE RD', 'HANDY RIDGE RD', 'HARMONY RD',
#        'HARTSTRAIT', 'HERITAGE WAY', 'I-69', 'I-69 - 123 - C',
#        'I-69 117 F', 'I-69 117.5', 'I-69 N', 'I-69 N RAMP', 'I-69 NB',
#        'I-69 S', 'I-69 S 129.5', 'I-69 S RAMP', 'I-69 SB OFF-RAMP',
#        'I-69117', 'IN 45 BYPASS', 'INDUSTRIAL BLVD', 'KINSER PK',
#        'LEIGHTON LN', 'LEONARD SPRINGS RD', 'LIBERTY DR', 'LOW GAP RD',
#        'MAIN', 'MAPLE GROVE WEST', 'MARIE LN', 'MATTHEWS', 'MCNEELY',
#        'MORNINGSIDE DR', 'N ADAMS ST', 'N ARLINGTON PARK DR',
#        'N BOTTOM RD', 'N BROOKWOOD DR', 'N BUTCHER RD', 'N COLLEGE AVE',
#        'N CURRY PK', 'N DANIELS WAY', 'N DEER PARK DR', 'N DUNN ST',
#        'N DUNN ST EVOLVE APTS', 'N EAGLESON AVE', 'N FEE LN',
#        'N FESS AVE', 'N FORREST AVE', 'N GATES DR', 'N GATES DR.',
#        'N GRANT ST', 'N HARTSTRAIT RD', 'N HEADLEY RD', 'N ILLINOIS ST',
#        'N INDIANA AVE', 'N JACKSON ST', 'N JACOB DR', 'N KINSER PK',
#        'N KINSER PK ', 'N LEE PAUL RD', 'N LINCOLN', 'N LINCOLN ST',
#        'N LOUDEN RD', 'N LYDY RD', 'N MADISON', 'N MADISON ST',
#        'N MAPLE ST', 'N MATHEWS DR', 'N MATTEWS DR', 'N MATTHEWS RD',
#        'N MILLER RD', 'N MILO B SAMPSON LN', 'N MONROE ST', 'N MORTON ST',
#        'N MT GILEAD', 'N MT GILEAD RD', 'N MT GILEAD TD', 'N MT TABOR',
#        'N MT TABOR RD', 'N OARD RD', 'N PACKING HOUSE RD', 'N PARK AVE',
#        'N PETE LLIS DR', 'N PINE ST', 'N PLYMOUTH RD', 'N PROW RD',
#        'N RANGE RD', 'N RIDGEWOOD DR', 'N ROGERS ST', 'N RUSSELL RD',
#        'N SALE ST', 'N SASSAFRAS DR', 'N SHELLY DR', 'N SHOWERS',
#        'N SHUFFLE CREEK RD', 'N SMITH PK', 'N SMITH RD', 'N ST RD 37',
#        'N ST RD 45/46 BYPASS', 'N ST RD 46', 'N ST RD 69',
#        'N STINESVILLE RD', 'N STONE MILL RD', 'N SUNRISE DR',
#        'N TEXAS RIDGE RD', 'N THOMAS RD', 'N THOMPSON RD',
#        'N THORNTREE DR', 'N TUNNEL RD', 'N UNION CT', 'N UNION ST',
#        'N UNION VALLEY RD', 'N UPPER BIRDIE GALYAN RD', 'N WALNUT',
#        'N WALNUT ST', 'N WASHINGTON ST', 'N WAYPORT RD', 'N WILLIS DR',
#        'N WOODBRIDGE DR', 'N WOODLAWN AVE', 'PAYNETOWN RD',
#        'PAYNETOWN RD.', 'PETE LLIS DR', 'PINEHURST DR', 'PINEMEADOW DR',
#        'POINTE RD', 'RAMP I-69-125-G', 'RED ROCK RD', 'RHORER RD',
#        'RICHLAND PLAZA', 'ROCKPORT', 'ROGERS ST', 'S 5TH', 'S ADAMS ST',
#        'S ADAMS ST ', 'S AUTO MALL RD', 'S AZALEA LN', 'S BAINBRIDGE DR',
#        'S BASSWOOD DR', 'S BASSWOOD DR APT B', 'S BREEDEN RD',
#        'S BRENDA LN', 'S BUFFSTONE CT', 'S CLARIZZ BLVD', 'S COLLEGE AVE',
#        'S COLLEGE MALL R', 'S COLLEGE MALL RD', 'S COLLEGE MALL RD.',
#        'S COPPER BEECH WAY', 'S CORY LN', 'S CURRY PK', 'S DAVISSON ST',
#        'S DEBORAH DR', 'S DEER TRCE', 'S DR', 'S DUNCAN RD',
#        'S DUNLAP RD', 'S DUNN ST', 'S EAGLESON AVE', 'S EDGEWOOD DR',
#        'S ELEMENT WAY', 'S ENDWRIGHT RD', 'S FAIRFAX RD', 'S FESS AVE',
#        'S FRANKLIN RD', 'S GARRISON CHAPEL RD', 'S GRANT ST',
#        'S GRAYWELL DR', 'S HARMONY', 'S HARMONY RD', 'S HENDERSON',
#        'S HENDERSON ST', 'S HIGH ST', 'S HIGHLAND AVE', 'S HIGHLAND AVE ',
#        'S HOFF LN', 'S HUNTINGTON DR', 'S HWY 446', 'S IN 46',
#        'S INDIANA AVE', 'S ISON RD', 'S JEFFERSON ST', 'S KINGSTON DR',
#        'S KIRBY RD', 'S LAKE RIDGE', 'S LANDMARK AVE',
#        'S LEONARD SPRINGS RD', 'S LIBERTY DR', 'S LIBERTY DR ',
#        'S LIBERTY DR.', 'S LINCOLN ST', 'S MARKET PL', 'S MILTON DR',
#        'S MITCHELL ST', 'S MORTON ST', 'S MULLER PARKWAY',
#        'S MULLER PKWY', 'S OVERHILL DR', 'S PALMER AVE', 'S PARK AVE',
#        'S PARK RIDGE RD', 'S PATTERSON DR', 'S PECAN LN',
#        'S PETE LLIS DR', 'S PIAZZA DR', 'S RAMSEY DR', 'S REISNER RD',
#        'S RENWICK BLVD', 'S ROCKPORT RD', 'S ROGERS', 'S ROGERS ST',
#        'S ROLLING RIDGE WAY', 'S ROSE AVE', 'S SALE ST', 'S SARE RD',
#        'S SIMS LN', 'S SMITH RD', 'S SNODDY RD', 'S SOCIETY LN',
#        'S SPICEWOOD LN', 'S ST RD 37', 'S ST RD 446', 'S ST RD 46',
#        'S ST RD. 37', 'S STRAIN RIDGE RD', 'S STRAINRIDGE RD',
#        'S STRONG DR', 'S SUGAR MAPLE CT', 'S SWAIN AVE', 'S TARZIAN LN',
#        'S UNION ST', 'S VICTOR PK', 'S VILLAGE DR', 'S WALNUT',
#        'S WALNUT SPRINGS DR', 'S WALNUT ST', 'S WALNUT ST ',
#        'S WALNUT ST PK', 'S WALNUT ST SUITE D', 'S WASHINGTON',
#        'S WASHINGTON ST', 'S WEIMER RD', 'S WESTMONT', 'S WESTPLEX AVE',
#        'S WESTWOOD DR', 'S WILLIAMSBURG DR', 'S WINFIELD RD',
#        'S WINSLOW CT', 'S WISLEY LN', 'S WOODLAWN AVE', 'S WOODSCREST DR',
#        'S YOST AVE', 'SALE', 'SARE RD', 'SB ON-RAMP I-69', 'SECOND',
#        'SERVICE RD', 'SHELLY', 'SHIELD RIDGE RD', 'SHILO RD', 'ST RD 37',
#        "ST RD 37 3800' N OF INGRAM RD", 'ST RD 446', 'ST RD 45',
#        'ST RD 45 46', 'ST RD 45 E', 'ST RD 45 W', 'ST RD 45/46',
#        'ST RD 45/46 BYPASS', 'ST RD 46', 'ST RD 46 W', 'ST RD 46 WEST',
#        'ST RD 48', 'STATE HIGH 46', 'STONEGATE DR', 'TEMPERANCE',
#        'TEMPERTANCE', 'TEXAS RIDGE', 'TOWER RIDGE RD', 'TRAILRIDGE RD',
#        'UNION VALLEY', 'VERNAL', 'W 10TH ST', 'W 11TH', 'W 11TH ST',
#        'W 12 ST', 'W 12TH ST', 'W 13TH ST', 'W 14TH ST', 'W 15TH ST',
#        'W 16TH ST', 'W 17TH ST', 'W 1ST', 'W 2ND ST', 'W 2ND ST ',
#        'W 3RD ST', 'W 3RD ST ', 'W 4TH ST', 'W 6TH ST', 'W 7TH ST',
#        'W 8TH ST', 'W 9TH ST', 'W AIRPORT RD', 'W ALLEN ST',
#        'W APPLE TREE CT', 'W ARLINGTON RD', 'W ARLINGTON VALLEY DR',
#        'W BELLE AVE', 'W BLOOMFIELD RD', 'W BRIGHTON RD', 'W CHEROKEE DR',
#        'W CHURCH LN', 'W CLUB HOUSE DR', 'W COOLIDGE DR',
#        'W COUNTRY CLUB DR', 'W DELAP RD', 'W DILLMAN RD', 'W DIXIE ST',
#        'W DODDS ST', 'W DRISCOLL ST', 'W DUNCAN DR', 'W DUVALL RD',
#        'W FARMER AVE', 'W FLUCK MILL', 'W FLUCK MILL RD',
#        'W FULLERTON PK', 'W GARDNER RD', 'W GATEWOOD DR', 'W GEORGIA AVE',
#        'W GIFFORD RD', 'W GORDON PK', 'W GOURLEY PK', 'W GRANITE DR',
#        'W GRIMES LN', 'W GRIMES ST', 'W HEDGEWOOD DR', 'W HENNESSEY ST',
#        'W INDUSTRIAL BLVD', 'W JACOB DR', 'W KIRKWOOD AVE',
#        'W KIRWOOD AVE', 'W LEONARD SPRINGS RD', 'W LILAC LN',
#        'W LOST MANS LN', 'W MAIN ST', 'W MAPLE GROVE RD', 'W MARBLE LN',
#        'W MARLENE DR', 'W MARQUIS DR', 'W MAY RD', 'W MCNEELY',
#        'W MCNEELY ST', 'W MORAVEC WAY', 'W PATTERSON DR', 'W PERRY DR',
#        'W POPCORN RD', 'W RATLIFF RD', 'W REEVES', 'W REEVES RD',
#        'W RICHLAND PLAZA DR', 'W RITTER', 'W RUNKLE WAY', 'W SMITH AVE',
#        'W SOUTHERN DR', 'W ST RD 45', 'W ST RD 45/46', 'W ST RD 46',
#        'W ST RD 48', 'W TAPP RD', 'W TEMPERANCE', 'W TEMPERANCE ST',
#        'W THAT RD', 'W VERNAL', 'W VERNAL PK', 'W VINE', 'W VINE ST',
#        'W WALKER LN', 'W WHITEHALL CROSSING BLVD', 'W WILLIAMS RD',
#        'W WOODHAVEN DR', 'W WOODYARD RD', 'W17TH ST', 'WALNUT',
#        'WALNUT ST', 'WESTERN DR', 'WOODLAWN AVE'], dtype=object)

# %%
# clean_df.value_counts('Roadway Id')[:20]
clean_df
# Out:
#      Collision Date         Roadway Id      Intersecting Road Address Number
# 0        2022-01-07             I-69 N               ST RD 37
# 1        2022-01-08         ST RD 46 W              DEER PARK
# 2        2022-01-17           W REEVES
# 3        2022-01-04                3RD            S HAWTHORNE
# 4        2022-01-01        S HENDERSON             E HILLSIDE
# ...             ...                ...                    ...            ...
# 2245     2022-09-17  W COUNTRY CLUB DR             S ST RD 37
# 2246     2022-09-15          E 10TH ST              E 10TH ST
# 2247     2022-08-20  S COLLEGE MALL RD  E BUICK CADILLAC BLVD
# 2248     2022-06-09         S ST RD 37              MORMAN RD
# 2249     2022-08-31         S ST RD 37            S ROGERS ST
#
# [2250 rows x 4 columns]

# %%
clean_df['Intersection Id'] = clean_df['Roadway Id'] + ' | ' + clean_df['Intersecting Road']

# %%
clean_df['Intersection Id'].value_counts()[:30]
# Out:
# I-69 |                       60
# E 3RD ST |                   37
# W ST RD 45 |                 23
# S COLLEGE MALL RD |          20
# W 3RD ST |                   19
# S ST RD 37 |                 18
# N EAGLESON AVE |             15
# ST RD 46 |                   15
# E 10TH ST |                  14
# S WALNUT ST |                12
# W 3RD ST | S LIBERTY DR      11
# N WALNUT ST |                11
# N KINSER PK | ST RD 46       10
# ST RD 45 | E 17TH ST          9
# ST RD 45 | WALKWAY            9
# ST RD 46 | E 3RD ST           9
# S LIBERTY DR |                9
# ST RD 46 | N KINSER PK        8
# ST RD 45 | E 10TH ST          8
# W 3RD ST | S CURRY PK         8
# ST RD 45 |                    7
# W 3RD ST | ST RD 37           7
# S LIBERTY DR | W 3RD ST       7
# E 17TH ST |                   7
# I-69 S |                      7
# E 3RD ST | S PETE LLIS DR     7
# ST RD 37 |                    7
# W ST RD 46 |                  7
# ST RD 46 | EASTGATE LN        7
# E 3RD ST | S FESS AVE         6
# Name: Intersection Id, dtype: int64

# %% [markdown]
# # Applying the cleaning script to the master csv

# %%
master = pd.read_csv('data_output/master_crash.csv', 
                 usecols=['DateTime','Roadway Id','Intersecting Road', 'Vehicles Involved','Number Injured','Number Dead','Latitude','Longitude','Primary Factor','Reported_Location'],
#                  dtype={'Roadway Id': 'string'},
                 parse_dates=['DateTime']
                )
master
# Out:
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_33489/4253089002.py:1: DtypeWarning: Columns (3,4,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   master = pd.read_csv('data_output/master_crash.csv',
#        Vehicles Involved  Number Injured  Number Dead   Roadway Id  \
# 0                    1.0             0.0          0.0         I69N
# 1                    1.0             0.0          0.0        SR46W
# 2                    1.0             0.0          0.0     W REEVES
# 3                    2.0             0.0          0.0        THIRD
# 4                    2.0             0.0          0.0  S HENDERSON
# ...                  ...             ...          ...          ...
# 74617                NaN             0.0          0.0          NaN
# 74618                NaN             0.0          0.0          NaN
# 74619                NaN             0.0          0.0          NaN
# 74620                NaN             0.0          0.0          NaN
# 74621                NaN             1.0          0.0          NaN
#
#       Intersecting Road   Latitude  Longitude  \
# 0           STATE RD 37  38.329723 -86.509226
# 1             DEER PARK  39.212153 -86.587526
# 2                   NaN  39.235012 -86.676553
# 3           S HAWTHORNE  39.156888 -86.520324
# 4            E HILLSIDE  39.150640 -86.526960
# ...                 ...        ...        ...
# 74617               NaN   0.000000   0.000000
# 74618               NaN   0.000000   0.000000
# 74619               NaN   0.000000   0.000000
# 74620               NaN   0.000000   0.000000
# 74621               NaN   0.000000   0.000000
#
#                               Primary Factor            DateTime  \
# 0                   ANIMAL/OBJECT IN ROADWAY 2022-01-07 05:14:00
# 1                   ANIMAL/OBJECT IN ROADWAY 2022-01-08 08:35:00
# 2                         RAN OFF ROAD RIGHT 2022-01-17 07:33:00
# 3                       UNSAFE LANE MOVEMENT 2022-01-04 12:32:00
# 4              FAILURE TO YIELD RIGHT OF WAY 2022-01-01 05:33:00
# ...                                      ...                 ...
# 74617                    IMPROPER LANE USAGE 2003-10-06 17:00:00
# 74618                           UNSAFE SPEED 2003-11-03 08:00:00
# 74619             BRAKE FAILURE OR DEFECTIVE 2003-12-05 12:00:00
# 74620                         UNSAFE BACKING 2003-12-01 07:00:00
# 74621  OTHER (DRIVER) - EXPLAIN IN NARRATIVE 2003-12-07 17:00:00
#
#            Reported_Location
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 74617  DUNN & WHITE LOT WEST
# 74618        RED OAK & SR446
# 74619        2ND ST & WALNUT
# 74620         NINETH & NORTH
# 74621      MONROW & THIRD ST
#
# [74622 rows x 10 columns]

# %% [markdown]
# For the 2003-2012 data, there is the added complexity of the `Reported_Location` column, which was formatted differently than later data. Let's separate that into the existing `Roadway Id` and `Intersecting Road` columns so that data can also be cleaned the same way.

# %%
master['Reported_Location'] = master['Reported_Location'].fillna('')
master['Roadway Id'] = master['Roadway Id'].fillna('')
master['Intersecting Road'] = master['Intersecting Road'].fillna('')

# %%
def get_year(date):
    return pd.to_datetime(date).year

# %%
master['Year'] = master['DateTime'].apply(get_year)

# %%
def split(row):
    return row.split("&")[0]
def split1(row):
    return row.split("&")[1] if len(row.split("&")) > 1 else ''

# %%
master['Reported_Location'].apply(split).sample(10)
# Out:
# 27247
# 20764
# 67
# 48004    FAIRVIEW
# 5664
# 42722    EASTGATE
# 57101     HARMONY
# 72090       3RD ST
# 66925     10TH ST
# 36841      DUNLAP
# Name: Reported_Location, dtype: object

# %%
master['Roadway Id'] = (master['Roadway Id'] + master['Reported_Location'].apply(split))

# %%
master['Intersecting Road'] = (master['Intersecting Road'] + master['Reported_Location'].apply(split1))

# %%
master[master['Year'] < 2013].sample(10)
# Out:
#        Vehicles Involved  Number Injured  Number Dead       Roadway Id  \
# 45388                NaN             0.0          0.0  BUSINESS 37 RD
# 59575                NaN             1.0          0.0             3RD
# 49989                NaN             0.0          0.0          SR4546
# 34533                NaN             0.0          0.0             9TH
# 48577                NaN             0.0          0.0      FAIRINGTON
# 43320                NaN             0.0          0.0           CURRY
# 41325                NaN             0.0          0.0           CURRY
# 41298                NaN             0.0          0.0          SR446S
# 52335                NaN             0.0          0.0   BLOOMFIELD RD
# 71584                NaN             0.0          0.0           7TH ST
#
#          Intersecting Road   Latitude  Longitude  \
# 45388           STONE MILL   0.000000   0.000000
# 59575          COLLEGE AVE  39.164640 -86.534816
# 49989            WALNUT ST  39.186368 -86.534400
# 34533        N COLLEGE AVE  39.170544 -86.534768
# 48577   LEONARD SPRINGS RD  39.136144 -86.582496
# 43320          WEST 3RD ST  39.164480 -86.560150
# 41325                 SR37   0.000000   0.000000
# 41298          TOWER RIDGE   0.000000   0.000000
# 52335                 CORY  39.157100 -86.559690
# 71584                       39.168640 -86.529486
#
#                                  Primary Factor            DateTime  \
# 45388                     FOLLOWING TOO CLOSELY 2010-11-01 17:00:00
# 59575                          IMPROPER TURNING 2006-06-05 23:00:00
# 49989  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE 2008-11-02 17:00:00
# 34533                        RAN OFF ROAD RIGHT 2012-09-05 11:00:00
# 48577             FAILURE TO YIELD RIGHT OF WAY 2009-06-07 15:00:00
# 43320             FAILURE TO YIELD RIGHT OF WAY 2010-02-07 17:00:00
# 41325                  ANIMAL/OBJECT IN ROADWAY 2011-11-03 21:00:00
# 41298             FAILURE TO YIELD RIGHT OF WAY 2011-10-02 12:00:00
# 52335                       ALCOHOLIC BEVERAGES 2008-04-06 21:00:00
# 71584     OTHER (DRIVER) - EXPLAIN IN NARRATIVE 2003-07-06 09:00:00
#
#                      Reported_Location    Year
# 45388      BUSINESS 37 RD & STONE MILL  2010.0
# 59575                3RD & COLLEGE AVE  2006.0
# 49989               SR4546 & WALNUT ST  2008.0
# 34533              9TH & N COLLEGE AVE  2012.0
# 48577  FAIRINGTON & LEONARD SPRINGS RD  2009.0
# 43320              CURRY & WEST 3RD ST  2010.0
# 41325                     CURRY & SR37  2011.0
# 41298             SR446S & TOWER RIDGE  2011.0
# 52335             BLOOMFIELD RD & CORY  2008.0
# 71584                           7TH ST  2003.0

# %%
# replace NA values with empty strings to make cleaning easier
master['Roadway Id'] = master['Roadway Id'].fillna('')
master['Intersecting Road'] = master['Intersecting Road'].fillna('')

# %%
clean_master = master
for string in strs_to_replace:
    clean_master = replace_str(clean_master,string[0],string[1])

# %%
# remove all info in parentheses in street names
def remove_parens(row):
    return " ".join(re.sub('\(.*\)', '', row).split())

# %%
clean_master['Roadway Id'] = clean_master['Roadway Id'].apply(extract_address_num)
clean_master['Roadway Id'] = clean_master['Roadway Id'].apply(colons)
clean_master['Roadway Id'] = clean_master['Roadway Id'].apply(number_streets)
clean_master['Roadway Id'] = clean_master['Roadway Id'].apply(remove_parens)

# %%
master[master['Roadway Id'].str.contains('2ND')]['Roadway Id'].value_counts()[:20]
# Out:
#   2ND ST            588
# 2ND ST              446
# 2ND                 364
# W 2ND ST             97
# E 2ND ST             42
# E 2ND ST             42
# E 2ND                38
# W 2ND                35
# 2ND ST               35
# E 2ND                12
# WEST 2ND ST          12
# EAST 2ND ST          11
# EAST 2ND ST           8
# 2ND ST ST             6
# 2ND SANDERS           6
# 2ND                   5
# 2ND STREET ST         3
# 2ND AVE SANDERS       3
# EAST 2ND              3
# 2ND STREET            2
# Name: Roadway Id, dtype: int64

# %%
clean_master[clean_master['Roadway Id'].str.contains('37')]['Roadway Id'].value_counts()[:20]
# Out:
# ST RD 37                          3861
# S ST RD 37                         683
# N ST RD 37                         506
# W ST RD 37                          52
# S ST RD 37 RD                       15
# OLDST RD 37                          8
# S ST RD 37 HWY                       8
# ST RD 37S                            4
# N ST RD 37 RD                        4
# CR37S                                4
# OFF RAMP FROM NB ST RD 37 RAMP       3
# S OLD ST RD 37                       3
# N S ST RD 37TATE                     3
# S ST RD 37 RAMP                      3
# State Road 37 45                     3
# State Road 37 ramp                   3
# N ST RD 37 BOUND                     2
# State Road 37 Ramp                   2
# ST RD 37W                            2
# N ST RD 37 HWY                       2
# Name: Roadway Id, dtype: int64

# %%
clean_master['Roadway Id'].value_counts()[:50]
# Out:
# 3RD ST               5030
# ST RD 37             3861
# ST RD 46             2594
# 10TH ST              2454
# ST RD 45             1791
# 17TH ST              1664
# E 3RD ST             1662
# ST RD 45/46          1501
# 2ND ST               1452
# 7TH ST                988
# ST RD 48              743
# S ST RD 37            683
# E 10TH ST             642
# W 3RD ST              611
# CURRY PK              593
# S WALNUT ST           553
# KIRKWOOD AVE          545
# 11TH ST               536
# EAGLESON AVE          526
# WALNUT ST             510
# N ST RD 37            506
# ST RD 446             498
# 6TH ST                495
# 4TH ST                471
# ATWATER AVE           462
# 8TH ST                426
# COLLEGE MALL RD       422
# 1ST ST                411
# ROGERS ST             380
# N WALNUT ST           376
# BLOOMFIELD RD         368
# COLLEGE AVE           347
# WALNUT                342
# 14TH ST               340
# 9TH ST                336
# FAIRFAX RD            332
# DUNN                  322
# 13TH ST               312
# E 17TH ST             312
# I-69 S                282
# HENDERSON ST          275
# CURRY                 256
# I-69                  254
# HILLSIDE DR           252
# LIBERTY DR            247
# I-69 N                237
# S COLLEGE MALL RD     227
# COUNTRY CLUB DR       224
# FEE LN                221
# N COLLEGE AVE         213
# Name: Roadway Id, dtype: int64

# %%
clean_master_min = clean_master[['Number Injured','Number Dead','Roadway Id','Intersecting Road','Latitude','Longitude','Primary Factor','DateTime']]

# %%
clean_master_min.to_csv(r'./data_output/master_crash_clean.csv', index=False)

# %% [markdown]
# ## A brief look at the intersections with the most crashes

# %%
clean_master = clean_master[clean_master['Roadway Id'] != '']

# %%
master_intersections = clean_master[clean_master['Intersecting Road'] != '']

# %%
# what proportion of master crashes with a Roadway Id listed had an Intersecting Road listed?
master_intersections.shape[0] / clean_master.shape[0]
# Out:
# 0.8366524228009352

# %%
master_intersections[master_intersections['Roadway Id'].str.contains("EAGLESON")]
# Out:
#        Vehicles Involved  Number Injured  Number Dead      Roadway Id  \
# 22                   2.0             0.0          0.0  N EAGLESON AVE
# 74                   2.0             0.0          0.0  N EAGLESON AVE
# 102                  2.0             0.0          0.0  S EAGLESON AVE
# 103                  1.0             1.0          0.0  N EAGLESON AVE
# 112                  2.0             0.0          0.0  N EAGLESON AVE
# ...                  ...             ...          ...             ...
# 74530                NaN             0.0          0.0    EAGLESON AVE
# 74536                NaN             1.0          0.0    EAGLESON AVE
# 74572                NaN             0.0          0.0    EAGLESON AVE
# 74574                NaN             0.0          0.0    EAGLESON AVE
# 74607                NaN             0.0          0.0    EAGLESON AVE
#
#            Intersecting Road   Latitude  Longitude  \
# 22                  E LAW LN  39.173462 -86.515488
# 74                 E 10TH ST  39.171215 -86.515681
# 102            E ATWATER AVE   0.000000   0.000000
# 103              N FISHER CT  39.183754 -86.516011
# 112                E 10TH ST  39.171810 -86.515652
# ...                      ...        ...        ...
# 74530                READ W    0.000000   0.000000
# 74536            LIBRARY LOT   0.000000   0.000000
# 74572   MUSICALS ARTS CENTER   0.000000   0.000000
# 74574            KAPPA DEKTA   0.000000   0.000000
# 74607               LIBRARY    0.000000   0.000000
#
#                            Primary Factor            DateTime  \
# 22                  FOLLOWING TOO CLOSELY 2022-01-19 08:55:00
# 74          FAILURE TO YIELD RIGHT OF WAY 2022-04-19 18:40:00
# 102         FAILURE TO YIELD RIGHT OF WAY 2022-02-27 12:30:00
# 103                      IMPROPER PASSING 2022-05-27 16:00:00
# 112                    UNSAFE LN MOVEMENT 2022-05-06 17:55:00
# ...                                   ...                 ...
# 74530                      UNSAFE BACKING 2003-11-03 22:00:00
# 74536  OTHER (DRR) - EXPLAIN IN NARRATIVE 2003-12-05 11:00:00
# 74572                      UNSAFE BACKING 2003-03-06 11:00:00
# 74574  OTHER (DRR) - EXPLAIN IN NARRATIVE 2003-05-02 12:00:00
# 74607       FAILURE TO YIELD RIGHT OF WAY 2003-09-01 21:00:00
#
#                          Reported_Location    Year
# 22                                          2022.0
# 74                                          2022.0
# 102                                         2022.0
# 103                                         2022.0
# 112                                         2022.0
# ...                                    ...     ...
# 74530               EAGLESON AVE & READ W   2003.0
# 74536           EAGLESON AVE & LIBRARY LOT  2003.0
# 74572  EAGLESON AVE & MUSICALS ARTS CENTER  2003.0
# 74574           EAGLESON AVE & KAPPA DEKTA  2003.0
# 74607              EAGLESON AVE & LIBRARY   2003.0
#
# [550 rows x 11 columns]

# %%
master_intersections['Intersecting Road'].value_counts()[:50]
# Out:
# WALNUT ST          1322
#  WALNUT ST          961
#  ST RD 45           893
#  ST RD 37           892
#  WALNUT             786
#  ST RD 46           761
#  EAGLESON AVE       708
# COLLEGE AVE         655
#  ST RD 45 W         632
#  ST RD 46 W         593
#  COLLEGE AVE        558
#  ST RD 46E          529
#  VERNAL             509
#  S ST RD 37         481
#  N ST RD 37         445
#  WOODLAWN           407
# EAGLESON AVE        379
#  W 3RD ST           372
# DUNN ST             371
#  ROGERS             335
# VERNAL PK           330
# ST RD 45            328
#  ROGERS ST          326
# CURRY PK            305
# INDIANA AVE         298
#  INDIANA AVE        296
# ST RD 37            290
# ROGERS ST           284
# LIBERTY DR          280
#  LINCOLN            280
#  INDIANA            275
#  WASHINGTON         270
# WOODLAWN AVE        263
# ST RD 48            258
#  COLLEGE            257
#  3RD ST             253
# ST RD 46            250
#  ST RD 45E          246
# 10TH ST             245
#  S WALNUT ST        233
#  ST RD 48           225
# TAPP RD             215
# KINSER PK           211
#  GRANT              211
#  FEE                208
#  SMITH              202
# COLLEGE MALL RD     202
#  DUNN               198
# WASHINGTON ST       193
#  FESS               191
# Name: Intersecting Road, dtype: int64
