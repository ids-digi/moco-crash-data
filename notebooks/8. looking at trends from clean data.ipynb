# %% [markdown]
# # Exploring trends in the cleaned data
# This notebook will delve into some trends of the crash data, which are included in the article that published alongside the crash dashboard.
#
# Before running this notebook, you should run the cleaning scripts in the `cleaning-workflow/cleaning-scripts` folder on Github using the instructions in the `readme` document. This notebook will analyze the `master-crash.csv` file which is generated at the end of the cleaning process.

# %%
# basic data/viz libraries
import pandas as pd
from matplotlib import pyplot as plt
from datetime import date, time

import altair as alt
# saving data into a file rather than embedding into the chart
alt.data_transformers.enable('json')
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
# read in the cleaned master csv
crash_df = pd.read_csv('../data/clean-data/master-crashes.csv', low_memory=False)

# %% [markdown]
# ## Trends over time

# %% [markdown]
# First, let's see some time trends. How has the frequency of crashes and crash injuries/fatalities changed over the time span of the dataset?

# %%
def get_year(date):
    return pd.to_datetime(date).year

# %%
def get_month(date):
    return pd.to_datetime(date).month

# %%
crash_df['Year'] = crash_df['DateTime'].apply(get_year)
crash_df['Month'] = crash_df['DateTime'].apply(get_month)

# %%
# set up function to create line chart with altair
def make_line_chart(source, title, values, x_axis, y_axis):
    return alt.Chart(source, 
          width=500,
          height=300, 
          title=title,
    ).mark_line().encode(
        alt.X(x_axis, axis=alt.Axis(
                values=values,
                grid=True,
                labelAngle=0)
             ),
        alt.Y(y_axis),
    )

# %%
annual_crash_counts = crash_df.groupby(by="Year").size().reset_index().rename(columns={0:"Crash count"})
# annual_crash_counts

# %%
source = annual_crash_counts
title='Car crashes year by year in Monroe County, IN'
values=annual_crash_counts['Year'].unique()
x_axis='Year:N'
y_axis='Crash count:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
monthly_crash_counts = crash_df.groupby(by="Month").size().reset_index().rename(columns={0:"Crash count"})
monthly_crash_counts['Crash count'] = monthly_crash_counts['Crash count'].apply(lambda x: x / len(monthly_crash_counts['Month'].unique()))
# monthly_crash_counts

# %%
# total crashes per month
source = monthly_crash_counts
title='Average number of car crashes per month (data from 2003-2022)'
values=monthly_crash_counts['Month'].unique()
# values=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
x_axis='Month:Q'
y_axis='Crash count:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
annual_fatalities = crash_df[crash_df['Number Dead'] > 0].groupby(by="Year").size().reset_index().rename(columns={0:"Fatality count"})
# annual_fatalities

# %%
# fatalities per year
# 2003-2012 ARE LOW ESTIMATES
counts = []
years = crash_df['Year'].unique()
for year in years:
    year_df = crash_df[crash_df['Year']==year]
    counts.append(year_df[year_df['Number Dead'] > 0]['Year'].count())
    
years, counts = zip(*sorted(zip(years, counts)))
source = pd.DataFrame({
  'Year': years,
  'Number of Crash Deaths': counts
})
title='Crash deaths by year in Monroe County, IN (data from 2003-22)'
values=years
x_axis='Year:O'
y_axis='Number of Crash Deaths:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# fatalities per year as a proportion of total crashes
# 2003-2012 ARE LOW ESTIMATES
counts = []
years = crash_df['Year'].unique()
for year in years:
    year_df = crash_df[crash_df['Year']==year]
    counts.append(year_df[year_df['Number Dead'] > 0]['Year'].count() / year_df.shape[0] * 1000)
    
years, counts = zip(*sorted(zip(years, counts)))
source = pd.DataFrame({
  'Year': years,
  'Deaths per every 1,000 crashes': counts
})
title='Deaths per every 1,000 crashes'
values=years
x_axis='Year:O'
y_axis='Deaths per every 1,000 crashes:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# injuries per year
# 2003-2012 ARE LOW ESTIMATES
counts = []
years = crash_df['Year'].unique()
for year in years:
    year_df = crash_df[crash_df['Year']==year]
    counts.append(year_df[year_df['Number Injured'] > 0]['Year'].count())
    
years, counts = zip(*sorted(zip(years, counts)))
source = pd.DataFrame({
  'Year': years,
  'Number of Crash Injuries': counts
})
title='Crash injuries by year in Monroe County, IN (data from 2003-22)'
values=years
x_axis='Year:O'
y_axis='Number of Crash Injuries:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# injuries per year as a proportion of total crashes
# 2003-2012 ARE LOW ESTIMATES
counts = []
years = crash_df['Year'].unique()
for year in years:
    year_df = crash_df[crash_df['Year']==year]
    counts.append(year_df[year_df['Number Injured'] > 0]['Year'].count() / year_df.shape[0] * 1000)
    
years, counts = zip(*sorted(zip(years, counts)))
source = pd.DataFrame({
  'Year': years,
  'Injuries per every 1,000 crashes': counts
})
title='Injuries per every 1,000 crashes'
values=years
x_axis='Year:O'
y_axis='Injuries per every 1,000 crashes:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# proportion of crashes that resulted in injury each month
months = crash_df['Month'].unique()
counts = []
for month in months:
    month_df = crash_df[crash_df['Month']==month]
    counts.append(year_df[year_df['Number Injured'] > 0]['Month'].count() / month_df.shape[0])
months, counts = zip(*sorted(zip(months, counts)))
month_names = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
months = month_names

source = pd.DataFrame({
  'Month': months,
  'Proportion of Injuries': counts
})
title='Proportion of Crashes that Involved Injury by Month'
values=month_names
x_axis='Month:O'
y_axis='Proportion of Injuries:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# proportion of crashes that resulted in death each month
months = crash_df['Month'].unique()
counts = []
for month in months:
    month_df = crash_df[crash_df['Month']==month]
    counts.append(year_df[year_df['Number Dead'] > 0]['Month'].count() / month_df.shape[0])
months, counts = zip(*sorted(zip(months, counts)))
month_names = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
months = month_names

source = pd.DataFrame({
  'Month': months,
  'Proportion of Fatalities': counts
})
title='Proportion of Crashes that Involved Fatalities by Month'
values=month_names
x_axis='Month:O'
y_axis='Proportion of Fatalities:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# ped_crashes_annual = 
annual_fatalities['Ped crashes'] = crash_df[crash_df['Pedestrian Involved'] == True].groupby(by="Year").size().reset_index()[0]
annual_fatalities['Bike crashes'] = crash_df[crash_df['Cyclist Involved'] == True].groupby(by="Year").size().reset_index()[0]
# annual_fatalities['Ped deaths'] = 
crash_df[(crash_df['Pedestrian Involved'] == True) & (crash_df['Number Dead'] > 0)].groupby(by="Year").size().reset_index()
# annual_fatalities
# Out:
#     Year  0
# 0   2008  3
# 1   2009  1
# 2   2010  1
# 3   2012  1
# 4   2014  2
# 5   2016  1
# 6   2017  1
# 7   2018  3
# 8   2019  2
# 9   2020  3
# 10  2022  2

# %%
crash_df[['Year','Number Injured','Number Dead','Pedestrian Involved']].groupby(by="Year").count()
# Out:
#       Number Injured  Number Dead  Pedestrian Involved
# Year
# 2003            4625         4625                    7
# 2004            4269         4269                    7
# 2005            3967         3967                    7
# 2006            3937         3937                   36
# 2007            4055         4055                   52
# 2008            4341         4341                   55
# 2009            4014         4014                   51
# 2010            4060         4060                   64
# 2011            3914         3914                   77
# 2012            4223         4223                   62
# 2013            3080         3080                   44
# 2014            3289         3289                   66
# 2015            4055         4055                   64
# 2016            4061         4061                   53
# 2017            3963         3963                   67
# 2018            3949         3957                   62
# 2019            3129         3133                   41
# 2020            2364         2364                   38
# 2021            3054         3057                   35
# 2022            3646         3646                   58

# %%
# what is the proportion of fatal crashes when pedestrians or cyclists
# are involved, compared with the overall fatality rate? 
# exclude years 2003-2005, which are outliers
bikeped_crashes = crash_df[crash_df['Year'] > 2005]

ped_involved = bikeped_crashes['Pedestrian Involved'] == True
bike_involved = bikeped_crashes['Cyclist Involved'] == True
bikeped_crashes[ped_involved | bike_involved]

fatality_rate_overall = bikeped_crashes[bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes.shape[0]
fatality_rate_ped = bikeped_crashes[ped_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[ped_involved].shape[0]
fatality_rate_bike = bikeped_crashes[bike_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[bike_involved].shape[0]
fatality_rate_bike_ped = bikeped_crashes[ped_involved | bike_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[ped_involved | bike_involved].shape[0]

print('Overall fatality rate:', fatality_rate_overall * 100, "%")
print('Pedestrian-involved crash fatality rate:', fatality_rate_ped * 100, "%")
print('Cyclist-involved crash fatality rate:', fatality_rate_bike * 100, "%")
print('Ped or cyclist involved crash fatality rate:', fatality_rate_bike_ped * 100, "%")
# Out:
# Overall fatality rate: 0.2359200088667923 %
# Pedestrian-involved crash fatality rate: 2.1621621621621623 %
# Cyclist-involved crash fatality rate: 0.1402524544179523 %
# Ped or cyclist involved crash fatality rate: 1.2239902080783354 %
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1868281209.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fatality_rate_ped = bikeped_crashes[ped_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[ped_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1868281209.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fatality_rate_bike = bikeped_crashes[bike_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[bike_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1868281209.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fatality_rate_bike_ped = bikeped_crashes[ped_involved | bike_involved][bikeped_crashes['Number Dead'] > 0].shape[0] / bikeped_crashes[ped_involved | bike_involved].shape[0]

# %%
# what about injury rates? 

# what is the proportion of fatal crashes when pedestrians or cyclists
# are involved, compared with the overall fatality rate? 
injury_rate_overall = bikeped_crashes[bikeped_crashes['Number Injured'] > 0].shape[0] / bikeped_crashes.shape[0]
injury_rate_ped = bikeped_crashes[ped_involved][crash_df['Number Injured'] > 0].shape[0] / bikeped_crashes[ped_involved].shape[0]
injury_rate_bike = bikeped_crashes[bike_involved][crash_df['Number Injured'] > 0].shape[0] / bikeped_crashes[bike_involved].shape[0]
injury_rate_bike_ped = bikeped_crashes[ped_involved | bike_involved][bikeped_crashes['Number Injured'] > 0].shape[0] / bikeped_crashes[ped_involved | bike_involved].shape[0]

injury_rate_overall * 100, injury_rate_ped * 100, injury_rate_bike * 100, injury_rate_bike_ped * 100

print('Overall injury rate:', injury_rate_overall * 100, "%")
print('Pedestrian-involved crash injury rate:', injury_rate_ped * 100, "%")
print('Cyclist-involved crash injury rate:', injury_rate_bike * 100, "%")
print('Ped or cyclist involved crash injury rate:', injury_rate_bike_ped * 100, "%")
# Out:
# Overall injury rate: 21.299301740107985 %
# Pedestrian-involved crash injury rate: 87.67567567567568 %
# Cyclist-involved crash injury rate: 81.62692847124825 %
# Ped or cyclist involved crash injury rate: 85.06731946144431 %
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1961542995.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   injury_rate_ped = bikeped_crashes[ped_involved][crash_df['Number Injured'] > 0].shape[0] / bikeped_crashes[ped_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1961542995.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   injury_rate_bike = bikeped_crashes[bike_involved][crash_df['Number Injured'] > 0].shape[0] / bikeped_crashes[bike_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/1961542995.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   injury_rate_bike_ped = bikeped_crashes[ped_involved | bike_involved][bikeped_crashes['Number Injured'] > 0].shape[0] / bikeped_crashes[ped_involved | bike_involved].shape[0]

# %%
crash_df
# Out:
#        Vehicles Involved  Number Injured  Number Dead  Roadway Id  \
# 0                    1.0             0.0          0.0      E 17TH
# 1                    1.0             0.0          0.0    E 3RD ST
# 2                    2.0             0.0          0.0  ST RD 46 W
# 3                    2.0             0.0          0.0   N DUNN ST
# 4                    1.0             0.0          0.0  ST RD 46 W
# ...                  ...             ...          ...         ...
# 76013                NaN             0.0          0.0        DUNN
# 76014                NaN             0.0          0.0     RED OAK
# 76015                NaN             0.0          0.0      2ND ST
# 76016                NaN             0.0          0.0      NINETH
# 76017                NaN             1.0          0.0      MONROW
#
#       Intersecting Road Corporate Limits?   Latitude  Longitude  \
# 0                   NaN                 Y  39.180909 -86.525593
# 1                   NaN                 Y  39.164783 -86.528648
# 2           W ARLINGTON                 N  39.207648 -86.573792
# 3        E KIRKWOOD AVE                 Y  39.166561 -86.528263
# 4             DEER PARK                 Y  39.212153 -86.587526
# ...                 ...               ...        ...        ...
# 76013    WHITE LOT WEST               NaN   0.000000   0.000000
# 76014         ST RD 446               NaN   0.000000   0.000000
# 76015            WALNUT               NaN   0.000000   0.000000
# 76016             NORTH               NaN   0.000000   0.000000
# 76017            3RD ST               NaN   0.000000   0.000000
#
#                               Primary Factor           Manner of Collision  \
# 0              FAILURE TO YIELD RIGHT OF WAY                     LEFT TURN
# 1      DRR DISTRACTED - EXPLAIN IN NARRATIVE  OTHER - EXPLAIN IN NARRATIVE
# 2                      FOLLOWING TOO CLOSELY                      REAR END
# 3              FAILURE TO YIELD RIGHT OF WAY                   RIGHT ANGLE
# 4                     ANIMAL/OBJECT IN RDWAY           COLLISION WITH DEER
# ...                                      ...                           ...
# 76013                      IMPROPER LN USAGE                           NaN
# 76014                           UNSAFE SPEED                           NaN
# 76015             BRAKE FAILURE OR DEFECTIVE                           NaN
# 76016                         UNSAFE BACKING                           NaN
# 76017     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
#
#                   DateTime  Address Number Cyclist Involved  \
# 0      2022-01-13 11:08:00             NaN              NaN
# 1      2022-10-13 13:31:00             NaN              NaN
# 2      2022-01-11 15:19:00             NaN              NaN
# 3      2022-01-24 04:27:00             NaN              NaN
# 4      2022-01-08 08:35:00             NaN              NaN
# ...                    ...             ...              ...
# 76013  2003-10-06 17:00:00             NaN              NaN
# 76014  2003-11-03 08:00:00             NaN              NaN
# 76015  2003-12-05 12:00:00             NaN              NaN
# 76016  2003-12-01 07:00:00             NaN              NaN
# 76017  2003-12-07 17:00:00             NaN              NaN
#
#       Pedestrian Involved
# 0                    True
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 76013                 NaN
# 76014                 NaN
# 76015                 NaN
# 76016                 NaN
# 76017                 NaN
#
# [76018 rows x 14 columns]

# %%
# % change from 2010 for diff crash severities
y10 = crash_df['Year'] == 2010
y22 = crash_df['Year'] == 2022
y10_injury_pct =  crash_df[y10][crash_df['Number Injured'] > 0].shape[0] / crash_df[y10].shape[0]
y10_death_pct = crash_df[y10][crash_df['Number Dead'] > 0].shape[0] / crash_df[y10].shape[0]

y22_injury_pct =  crash_df[y22][crash_df['Number Injured'] > 0].shape[0] / crash_df[y22].shape[0]
y22_death_pct = crash_df[y22][crash_df['Number Dead'] > 0].shape[0] / crash_df[y22].shape[0]

'pct change in crash deaths, 2010 - 2022:', (y22_death_pct - y10_death_pct) / y10_death_pct
'pct change in crash injuries, 2010 - 2022:', (y22_injury_pct - y10_injury_pct) / y10_injury_pct
# Out:
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/2048127043.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y10_injury_pct =  crash_df[y10][crash_df['Number Injured'] > 0].shape[0] / crash_df[y10].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/2048127043.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y10_death_pct = crash_df[y10][crash_df['Number Dead'] > 0].shape[0] / crash_df[y10].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/2048127043.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y22_injury_pct =  crash_df[y22][crash_df['Number Injured'] > 0].shape[0] / crash_df[y22].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/2048127043.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y22_death_pct = crash_df[y22][crash_df['Number Dead'] > 0].shape[0] / crash_df[y22].shape[0]
# ('pct change in crash injuries, 2010 - 2022:', -0.1642369104163384)

# %%
y10_injury_pct =  crash_df[y10][ped_involved][crash_df['Number Injured'] > 0].shape[0] / crash_df[y10][ped_involved].shape[0]
y10_death_pct = crash_df[y10][ped_involved][crash_df['Number Dead'] > 0].shape[0] / crash_df[y10][ped_involved].shape[0]

y22_injury_pct =  crash_df[y22][ped_involved][crash_df['Number Injured'] > 0].shape[0] / crash_df[y22][ped_involved].shape[0]
y22_death_pct = crash_df[y22][ped_involved][crash_df['Number Dead'] > 0].shape[0] / crash_df[y22][ped_involved].shape[0]

'pct change in pedestrian crash deaths, 2010 - 2022:', (y22_death_pct - y10_death_pct) / y10_death_pct
'pct change in pedestrian crash injuries, 2010 - 2022:', (y22_injury_pct - y10_injury_pct) / y10_injury_pct
# Out:
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/3949581595.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y10_injury_pct =  crash_df[y10][ped_involved][crash_df['Number Injured'] > 0].shape[0] / crash_df[y10][ped_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/3949581595.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y10_death_pct = crash_df[y10][ped_involved][crash_df['Number Dead'] > 0].shape[0] / crash_df[y10][ped_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/3949581595.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y22_injury_pct =  crash_df[y22][ped_involved][crash_df['Number Injured'] > 0].shape[0] / crash_df[y22][ped_involved].shape[0]
# /var/folders/1_/qczjy1pj211879j9qvrr2brh0000gn/T/ipykernel_32868/3949581595.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y22_death_pct = crash_df[y22][ped_involved][crash_df['Number Dead'] > 0].shape[0] / crash_df[y22][ped_involved].shape[0]
# ('pct change in pedestrian crash deaths, 2010 - 2022:', 1.206896551724138)

# %%
def series_avg(val1,val2):
    return val1 / val2 * 100

# %%
bike_ped_crashes = crash_df[((crash_df['Pedestrian Involved'] == True) | 
         (crash_df['Cyclist Involved'] == True)) & 
        (crash_df['Year'] > 2005)].groupby(by="Year").size().reset_index().rename(columns={
    0: "Bike/ped crashes"
})

# %%
bike_ped_injuries = crash_df[((crash_df['Pedestrian Involved'] == True) | 
         (crash_df['Cyclist Involved'] == True)) & 
        (crash_df['Number Injured'] > 0) & 
        (crash_df['Year'] > 2005)].groupby(by="Year").size().reset_index().rename(columns={
    0: "Bike/ped injuries"
})

bike_ped_injuries['Total bike/ped crashes'] = bike_ped_crashes['Bike/ped crashes']
bike_ped_injuries['Total crashes'] = crash_df[crash_df['Year'] > 2005].groupby(by="Year").size().reset_index()[0]
bike_ped_injuries['Total injuries'] = crash_df[crash_df['Year'] > 2005][['Year','Number Injured']].groupby(by="Year").sum().reset_index()['Number Injured']
bike_ped_injuries['bike/ped_pct'] = bike_ped_injuries.apply(lambda x: series_avg(x['Bike/ped injuries'],x['Total bike/ped crashes']), axis=1)
bike_ped_injuries['all_injuries_pct'] = bike_ped_injuries.apply(lambda x: series_avg(x['Total injuries'],x['Total crashes']), axis=1)

bike_ped_injuries
# Out:
#     Year  Bike/ped injuries  Total bike/ped crashes  Total crashes  \
# 0   2006                 63                      65           3937
# 1   2007                104                     115           4055
# 2   2008                 76                      89           4341
# 3   2009                 78                      88           4014
# 4   2010                 99                     115           4060
# 5   2011                110                     118           3914
# 6   2012                111                     128           4223
# 7   2013                 72                      90           3080
# 8   2014                 97                     113           3289
# 9   2015                 85                     100           4055
# 10  2016                 77                     101           4061
# 11  2017                 84                     107           3963
# 12  2018                 87                     109           3963
# 13  2019                 60                      75           3134
# 14  2020                 59                      69           2365
# 15  2021                 52                      58           3057
# 16  2022                 76                      94           3646
#
#     Total injuries  bike/ped_pct  all_injuries_pct
# 0           1050.0     96.923077         26.670053
# 1            941.0     90.434783         23.205919
# 2            875.0     85.393258         20.156646
# 3            878.0     88.636364         21.873443
# 4            926.0     86.086957         22.807882
# 5            831.0     93.220339         21.231477
# 6            944.0     86.718750         22.353777
# 7            936.0     80.000000         30.389610
# 8            971.0     85.840708         29.522651
# 9           1107.0     85.000000         27.299630
# 10          1106.0     76.237624         27.234671
# 11           960.0     78.504673         24.224073
# 12           885.0     79.816514         22.331567
# 13           844.0     80.000000         26.930440
# 14           667.0     85.507246         28.202960
# 15           806.0     89.655172         26.365718
# 16           902.0     80.851064         24.739440

# %%
bike_ped = crash_df[((crash_df['Pedestrian Involved'] == True) | 
         (crash_df['Cyclist Involved'] == True)) & 
        (crash_df['Year'] > 2005)].groupby(by="Year").size().reset_index().rename(columns={
    0: "Total bike/ped crashes"
})

# bike_ped

# %%
crash_df[((crash_df['Pedestrian Involved'] == True) | 
         (crash_df['Cyclist Involved'] == True)) &
         (crash_df['Number Dead'] > 0) 
        ].groupby(by='Year',dropna=False).sum()
# Out:
#       Vehicles Involved  Number Injured  Number Dead    Latitude   Longitude  \
# Year
# 2008                0.0             0.0          3.0  117.473638 -259.740053
# 2009                0.0             0.0          1.0   39.175674  -86.518987
# 2010                0.0             0.0          1.0   39.102732  -86.576999
# 2012                0.0             0.0          1.0   39.121450  -86.523827
# 2014                2.0             0.0          2.0   78.382589 -173.206988
# 2016                1.0             0.0          1.0   39.207040  -86.534704
# 2017                1.0             1.0          1.0   39.187230  -86.552182
# 2018                3.0             0.0          3.0   78.333424 -173.070891
# 2019                2.0             0.0          2.0   78.363098 -173.001543
# 2020                4.0             1.0          3.0   78.328880 -173.008496
# 2022                2.0             0.0          2.0   78.311192 -173.148750
#
#       Address Number  Month
# Year
# 2008             0.0     20
# 2009             0.0      9
# 2010             0.0     12
# 2012             0.0     12
# 2014             0.0     19
# 2016             0.0      7
# 2017             0.0      6
# 2018             0.0     33
# 2019             0.0     14
# 2020             0.0     23
# 2022             0.0     15

# %%
ped03 = crash_df[(crash_df['Year'] == 2003) & 
                 (crash_df['Number Dead'] > 0) & 
                 (crash_df['Pedestrian Involved'] == True)
                ].sum()
ped03
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [335], in <cell line: 1>()
# ----> 1 ped03 = crash_df[(crash_df['Year'] == 2003) &
#       2                  (crash_df['Number Dead'] > 0) &
#       3                  (crash_df['Pedestrian Involved'] == True)
#       4                 ].size()
#       5 ped03
#
# TypeError: 'numpy.int64' object is not callable

# %%
bike_ped_injuries.to_csv('../data/charts/bike-ped-injuries.csv')
bike_ped_deaths.to_csv('../data/charts/bike-ped-deaths.csv')

# %%
# injuries per year per 1000 total crashes from bike ped crashes
source = bike_ped_injuries[['Year','bike/ped_pct']]
title='Pedestrian or cyclist injuries for every 100 crashes'
values=years
x_axis='Year:O'
y_axis='bike/ped_pct:Q'

make_line_chart(source, title, values, x_axis, y_axis)
# Out:
# alt.Chart(...)

# %%
# what are the most dangerous intersections? 

fatal_crashes = crash_df['Number Dead'] > 0
injury_crashes = crash_df['Number Injured'] > 0

crash_df[injury_crashes|fatal_crashes].groupby(by=['Roadway Id','Intersecting Road']).size().sort_values(ascending=False)[:20]
# Out:
# Roadway Id       Intersecting Road
# ST RD 37         ST RD 45             92
#                  VERNAL PK            68
#                  ST RD 48             61
# ST RD 45/46      KINSER PK            56
# ST RD 37         TAPP RD              55
#                  VERNAL               50
# ST RD 48-3RD ST  LIBERTY DR           47
# N ST RD 37       VERNAL               47
# ST RD 37         ST RD 37             40
# ST RD 45/46      17TH ST              36
# ST RD 48         CURRY PK             34
# GRIMES LN        WALNUT ST            30
# DILLMAN          ST RD 37             30
# ST RD 37         DILLMAN RD           30
# ST RD 45/46      10TH ST              29
# FULLERTON        S ST RD 37           29
# 3RD ST           COLLEGE MALL         29
#                  EAGLESON AVE         28
# ST RD 45/46      WALNUT ST            27
# ST RD 48         GATES DR             27
# dtype: int64

# %%
bikeped_crashes.shape
# Out:
# (63157, 16)

# %%
bikeped_crashes[ped_involved | bike_involved].groupby(by=['Roadway Id','Intersecting Road', 'Year']).size().sort_values(ascending=False)[:20]
# Out:
# Roadway Id    Intersecting Road  Year
# 7TH           EAGLESON AVE       2012    5
#   7TH ST      EAGLESON AVE       2013    4
# DUNN          KIRKWOOD AVE       2010    3
# E 10TH        N SUNRISE DR       2019    3
#   2ND ST      COLLEGE AVE        2018    3
# KIRKWOOD AVE  WALNUT ST          2013    3
# 7TH           EAGLESON AVE       2007    3
#   3RD ST      WOODLAWN AVE       2015    3
# 10TH ST       UNION ST           2017    3
# EAGLESON AVE  JONES AVE          2017    3
# ST RD 45/46   10TH ST            2017    2
#   8TH ST      WALNUT ST          2013    2
# HILLVIEW      N ST RD 37 RD      2009    2
# ST RD 45/46   KINSER PK          2013    2
# DUNN          KIRKWOOD AVE       2008    2
# ST RD 45/46   KINSER PK          2015    2
#                                  2016    2
# 10TH ST       CAMPBELL ST        2017    2
#               EAGLESON AVE       2013    2
# ST RD 45/46   KINSER PK          2017    2
# dtype: int64

# %%
crash_df[crash_df['Primary Factor'].str.contains("DRR")]
# Out:
#        Vehicles Involved  Number Injured  Number Dead        Roadway Id  \
# 1                    1.0             0.0          0.0          E 3RD ST
# 18                   1.0             0.0          0.0          CURRY PK
# 31                   2.0             0.0          0.0  S COLLEGE MALL R
# 47                   2.0             0.0          0.0      N MADISON ST
# 61                   2.0             1.0          0.0          W 3RD ST
# ...                  ...             ...          ...               ...
# 75998                NaN             0.0          0.0               8TH
# 76000                NaN             0.0          0.0               FEE
# 76005                NaN             0.0          0.0  ST RD 45ST RD 46
# 76010                NaN             0.0          0.0       IU LIBRARY
# 76017                NaN             1.0          0.0            MONROW
#
#        Intersecting Road Corporate Limits?   Latitude  Longitude  \
# 1                    NaN                 Y  39.164783 -86.528648
# 18              ROLL AVE                 Y  39.147190 -86.582613
# 31                   NaN                 Y  39.153861 -86.495782
# 47                   NaN                 Y  39.168457 -86.537424
# 61            S CURRY PK                 Y  39.164651 -86.582897
# ...                  ...               ...        ...        ...
# 75998             9TH ST               NaN   0.000000   0.000000
# 76000  N SIDE FIELDHOUSE               NaN   0.000000   0.000000
# 76005             WALNUT               NaN   0.000000   0.000000
# 76010       EAGLESON AVE               NaN   0.000000   0.000000
# 76017             3RD ST               NaN   0.000000   0.000000
#
#                               Primary Factor           Manner of Collision  \
# 1      DRR DISTRACTED - EXPLAIN IN NARRATIVE  OTHER - EXPLAIN IN NARRATIVE
# 18        OTHER (DRR) - EXPLAIN IN NARRATIVE                    RAN OFF RD
# 31        OTHER (DRR) - EXPLAIN IN NARRATIVE  OPPOSITE DIRECTION SIDESWIPE
# 47        OTHER (DRR) - EXPLAIN IN NARRATIVE  OPPOSITE DIRECTION SIDESWIPE
# 61        OTHER (DRR) - EXPLAIN IN NARRATIVE                      REAR END
# ...                                      ...                           ...
# 75998     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
# 76000     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
# 76005     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
# 76010     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
# 76017     OTHER (DRR) - EXPLAIN IN NARRATIVE                           NaN
#
#                   DateTime  Address Number Cyclist Involved  \
# 1      2022-10-13 13:31:00             NaN              NaN
# 18     2022-01-13 12:52:00             NaN              NaN
# 31     2022-06-10 19:23:00             NaN              NaN
# 47     2022-08-06 00:00:00             NaN              NaN
# 61     2022-07-16 09:33:00             NaN              NaN
# ...                    ...             ...              ...
# 75998  2003-08-06 11:00:00             NaN              NaN
# 76000  2003-09-02 12:00:00             NaN              NaN
# 76005  2003-09-01 18:00:00             NaN              NaN
# 76010  2003-10-03 19:00:00             NaN              NaN
# 76017  2003-12-07 17:00:00             NaN              NaN
#
#       Pedestrian Involved  Year  Month
# 1                     NaN  2022     10
# 18                    NaN  2022      1
# 31                    NaN  2022      6
# 47                    NaN  2022      8
# 61                    NaN  2022      7
# ...                   ...   ...    ...
# 75998                 NaN  2003      8
# 76000                 NaN  2003      9
# 76005                 NaN  2003      9
# 76010                 NaN  2003     10
# 76017                 NaN  2003     12
#
# [10251 rows x 16 columns]

# %%
yearly_deaths = crash_df[['Year','Number Dead']].groupby(by='Year').sum()
yearly_deaths['Total Crashes'] = crash_df[['Year']].groupby(by='Year').size()
# how many deaths for every 100 crashes
yearly_deaths['Pct fatal'] = yearly_deaths.apply(lambda x: series_avg(x['Number Dead'],x['Total Crashes']),axis=1)

# %%
yearly_deaths.to_csv('../data/charts/annual-fatalities.csv')

# %%
yearly_injuries = crash_df[['Year','Number Injured']].groupby(by='Year').sum()
yearly_injuries['Total Crashes'] = crash_df[['Year']].groupby(by='Year').size()
# how many injuries for every 100 crashes
yearly_injuries['Pct injured'] = yearly_injuries.apply(lambda x: series_avg(x['Number Injured'],x['Total Crashes']),axis=1)
yearly_injuries
# Out:
#       Number Injured  Total Crashes  Pct injured
# Year
# 2003           985.0           4625    21.297297
# 2004          1230.0           4269    28.812368
# 2005          1107.0           3967    27.905218
# 2006          1050.0           3937    26.670053
# 2007           941.0           4055    23.205919
# 2008           875.0           4341    20.156646
# 2009           878.0           4014    21.873443
# 2010           926.0           4060    22.807882
# 2011           831.0           3914    21.231477
# 2012           944.0           4223    22.353777
# 2013           936.0           3080    30.389610
# 2014           971.0           3289    29.522651
# 2015          1107.0           4055    27.299630
# 2016          1106.0           4061    27.234671
# 2017           960.0           3963    24.224073
# 2018           885.0           3963    22.331567
# 2019           844.0           3134    26.930440
# 2020           667.0           2365    28.202960
# 2021           806.0           3057    26.365718
# 2022           902.0           3646    24.739440

# %%
yearly_injuries.to_csv('../data/charts/annual-injuries.csv')

# %%
crash_df[((crash_df['Pedestrian Involved'] == True) |
          crash_df['Cyclist Involved'] == True
         ) & (crash_df['Number Dead'] > 0)]
# Out:
#        Vehicles Involved  Number Injured  Number Dead       Roadway Id  \
# 544                  1.0             0.0          1.0      N WALNUT ST
# 3330                 1.0             0.0          1.0     W AIRPORT RD
# 7000                 1.0             0.0          1.0  S WASHINGTON ST
# 8391                 2.0             1.0          1.0    S INDIANA AVE
# 9007                 1.0             0.0          1.0         ST RD 46
# 10162                1.0             0.0          1.0         ST RD 45
# 11232                1.0             0.0          1.0         S WALNUT
# 12388                1.0             0.0          1.0              1ST
# 14555                1.0             0.0          1.0           3RD ST
# 20157                1.0             0.0          1.0         CURRY PK
# 23836                1.0             0.0          1.0       LINCOLN ST
# 24977                1.0             0.0          1.0         ST RD 37
# 30720                1.0             1.0          1.0      ST RD 45/46
# 31390                1.0             0.0          1.0         ST RD 46
# 38199                NaN             0.0          1.0            NIMIT
# 46226                NaN             0.0          1.0      COCKRELL RD
# 47711                NaN             0.0          1.0           FEE LN
# 52246                NaN             0.0          1.0           BRDWAY
# 52750                NaN             0.0          1.0         BEAUMONT
# 54230                NaN             0.0          1.0          AIRPORT
#
#       Intersecting Road Corporate Limits?   Latitude  Longitude  \
# 544           E 12TH ST                 Y  39.174286 -86.533570
# 3330         S KIRBY RD                 N  39.136906 -86.615180
# 7000           E 3RD ST               NaN  39.164640 -86.532400
# 8391           E 3RD ST               NaN        NaN        NaN
# 9007    S PARK RIDGE RD               NaN  39.164240 -86.476096
# 10162      N RUSSELL RD               NaN  39.198979 -86.467943
# 11232          E 3RD ST               NaN  39.164118 -86.533600
# 12388               NaN               NaN  39.177744 -86.539755
# 14555            RUNKLE               NaN   0.000000   0.000000
# 20157           BEASLEY               NaN  39.149152 -86.582704
# 23836          ALLEN ST               NaN  39.155680 -86.531136
# 24977         WALNUT ST               NaN  39.207040 -86.534704
# 30720      ARLINGTON RD               NaN  39.187230 -86.552182
# 31390            5TH ST               NaN  39.233437 -86.624284
# 38199         RHORER RD               NaN  39.121450 -86.523827
# 46226        S ROCKPORT               NaN  39.102732 -86.576999
# 47711        THIRTEENTH               NaN  39.175674 -86.518987
# 52246          CURRY PK               NaN  39.170917 -86.582970
# 52750       JOHNSON AVE               NaN  39.164870 -86.564970
# 54230          ST RD 45               NaN  39.137851 -86.592113
#
#                               Primary Factor  \
# 544       OTHER (DRR) - EXPLAIN IN NARRATIVE
# 3330   DRR DISTRACTED - EXPLAIN IN NARRATIVE
# 7000           FAILURE TO YIELD RIGHT OF WAY
# 8391               DISREGARD SIGNAL/REG SIGN
# 9007                       PEDESTRIAN ACTION
# 10162     OTHER (DRR) - EXPLAIN IN NARRATIVE
# 11232                      PEDESTRIAN ACTION
# 12388                         UNSAFE BACKING
# 14555                      PEDESTRIAN ACTION
# 20157                      PEDESTRIAN ACTION
# 23836            ENGINE FAILURE OR DEFECTIVE
# 24977                      PEDESTRIAN ACTION
# 30720                       RAN OFF RD RIGHT
# 31390                      PEDESTRIAN ACTION
# 38199                      PEDESTRIAN ACTION
# 46226     OTHER (DRR) - EXPLAIN IN NARRATIVE
# 47711                      PEDESTRIAN ACTION
# 52246                      PEDESTRIAN ACTION
# 52750                         LEFT OF CENTER
# 54230  DRR DISTRACTED - EXPLAIN IN NARRATIVE
#
#                       Manner of Collision             DateTime  \
# 544          OTHER - EXPLAIN IN NARRATIVE  2022-09-18 01:49:00
# 3330                           RAN OFF RD  2022-06-10 20:48:00
# 7000                           RIGHT TURN  2020-02-08 18:35:00
# 8391                          RIGHT ANGLE  2020-09-29 09:30:00
# 9007          COLLISION WITH OBJECT IN RD  2020-12-21 19:00:00
# 10162        OTHER - EXPLAIN IN NARRATIVE  2019-05-13 22:23:00
# 11232                          RIGHT TURN  2019-09-26 11:44:00
# 12388                       BACKING CRASH  2018-10-27 20:45:00
# 14555                        OBJECT IN RD  2018-12-21 18:04:00
# 20157  HEAD ON BETWEEN TWO MOTOR VEHICLES  2014-11-06 05:06:00
# 23836                               OTHER  2018-11-16 16:15:00
# 24977        OTHER - EXPLAIN IN NARRATIVE  2016-07-21 04:07:00
# 30720                          RAN OFF RD  2017-06-04 16:34:00
# 31390                       NON-COLLISION  2014-08-29 06:50:00
# 38199                                 NaN  2012-12-05 07:00:00
# 46226                                 NaN  2010-12-07 01:00:00
# 47711                                 NaN  2009-09-04 14:00:00
# 52246                                 NaN  2008-01-04 07:00:00
# 52750                                 NaN  2008-09-06 03:00:00
# 54230                                 NaN  2008-10-06 22:00:00
#
#        Address Number Cyclist Involved Pedestrian Involved  Year  Month
# 544               NaN              NaN                True  2022      9
# 3330              NaN              NaN                True  2022      6
# 7000              NaN              NaN                True  2020      2
# 8391              NaN              NaN                True  2020      9
# 9007              NaN              NaN                True  2020     12
# 10162             NaN             True                True  2019      5
# 11232             NaN              NaN                True  2019      9
# 12388             NaN              NaN                True  2018     10
# 14555             NaN              NaN                True  2018     12
# 20157             NaN              NaN                True  2014     11
# 23836             NaN              NaN                True  2018     11
# 24977             NaN              NaN                True  2016      7
# 30720             NaN              NaN                True  2017      6
# 31390             NaN              NaN                True  2014      8
# 38199             NaN              NaN                True  2012     12
# 46226             NaN              NaN                True  2010     12
# 47711             NaN              NaN                True  2009      9
# 52246             NaN              NaN                True  2008      1
# 52750             NaN              NaN                True  2008      9
# 54230             NaN              NaN                True  2008     10
